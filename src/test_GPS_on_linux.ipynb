# %%
import requests

# 例として、無料のIPベースの位置情報APIを使用
api_url = "https://ipinfo.io/json"

# APIリクエストを送信
response = requests.get(api_url)
data = response.json()

# 結果を表示
print(f'IP Address: {data["ip"]}')
print(f'Location: {data["loc"]}')
print(f'City: {data["city"]}')
print(f'Region: {data["region"]}')
print(f'Country: {data["country"]}')
# Out:
# IP Address: 210.159.31.94
# Location: 34.6937,135.5022
# City: Osaka
# Region: Ōsaka
# Country: JP

# %%
# !python --version
# Out:
# Python 3.11.4

# %%
# !poetry show
# Out:
# Skipping virtualenv creation, as specified in config file.
# affine                    2.4.0        Matrices describing affine transform...
# aiofiles                  23.2.1       File support for asyncio.
# altair                    5.1.2        Vega-Altair: A declarative statistic...
# annotated-types           0.5.0        Reusable constraint types to use wit...
# anyio                     3.7.1        High level compatibility layer for m...
# asttokens                 2.4.0        Annotate AST trees with source code ...
# attrs                     23.1.0       Classes Without Boilerplate
# backcall                  0.2.0        Specifications for callback function...
# beautifulsoup4            4.12.2       Screen-scraping library
# bqplot                    0.12.40      Interactive plotting for the Jupyter...
# branca                    0.6.0        Generate complex HTML+JS pages with ...
# brotli                    1.1.0        Python bindings for the Brotli compr...
# bs4                       0.0.1        Dummy package for Beautiful Soup
# cached-property           1.5.2        A decorator for caching properties i...
# cachetools                5.3.1        Extensible memoizing collections and...
# certifi                   2023.7.22    Python package for providing Mozilla...
# charset-normalizer        3.3.0        The Real First Universal Charset Det...
# click                     8.1.7        Composable command line interface to...
# click-plugins             1.1.1        An extension module for click to ena...
# cligj                     0.7.2        Click params for commmand line inter...
# colour                    0.1.5        converts and manipulates various col...
# comm                      0.1.4        Jupyter Python Comm implementation, ...
# commonmark                0.9.1        Python parser for the CommonMark Mar...
# contourpy                 1.1.1        Python library for calculating conto...
# cycler                    0.12.0       Composable style cycles
# debugpy                   1.8.0        An implementation of the Debug Adapt...
# decorator                 4.4.2        Decorators for Humans
# dictdiffer                0.9.0        Dictdiffer is a library that helps y...
# earthengine-api           0.1.374      Earth Engine Python API
# eerepr                    0.0.4        Code Editor-style reprs for Earth En...
# executing                 2.0.0        Get the currently executing AST node...
# fastapi                   0.103.2      FastAPI framework, high performance,...
# ffmpy                     0.3.1        A simple Python wrapper for ffmpeg
# filelock                  3.12.4       A platform independent file lock.
# folium                    0.14.0       Make beautiful maps with Leaflet.js ...
# fonttools                 4.43.0       Tools to manipulate font files
# fsspec                    2023.9.2     File-system specification
# future                    0.18.3       Clean single-source support for Pyth...
# geemap                    0.28.2       A Python package for interactive map...
# geocoder                  1.38.1       Geocoder is a simple and consistent ...
# google-api-core           2.12.0       Google API client core library
# google-api-python-client  2.102.0      Google API Client Library for Python
# google-auth               2.23.2       Google Authentication Library
# google-auth-httplib2      0.1.1        Google Authentication Library: httpl...
# google-cloud-core         2.3.3        Google Cloud API client core library
# google-cloud-storage      2.11.0       Google Cloud Storage API client library
# google-crc32c             1.5.0        A python wrapper of the C library 'G...
# google-resumable-media    2.6.0        Utilities for Google Media Downloads...
# googleapis-common-protos  1.60.0       Common protobufs used in Google APIs
# gradio                    3.47.0       Python library for easily interactin...
# gradio-client             0.6.0        Python library for easily interactin...
# h11                       0.14.0       A pure-Python, bring-your-own-I/O im...
# httpcore                  0.18.0       A minimal low-level HTTP client.
# httplib2                  0.22.0       A comprehensive HTTP client library.
# httpx                     0.25.0       The next generation HTTP client.
# huggingface-hub           0.17.3       Client library to download and publi...
# hupper                    1.12         Integrated process monitor for devel...
# idna                      3.4          Internationalized Domain Names in Ap...
# imageio                   2.31.5       Library for reading and writing a wi...
# imageio-ffmpeg            0.4.9        FFMPEG wrapper for Python
# importlib-resources       6.1.0        Read resources from Python packages
# ipyevents                 2.0.2        A custom widget for returning mouse ...
# ipyfilechooser            0.6.0        Python file chooser widget for use i...
# ipykernel                 6.25.2       IPython Kernel for Jupyter
# ipyleaflet                0.17.4       A Jupyter widget for dynamic Leaflet...
# ipython                   8.16.1       IPython: Productive Interactive Comp...
# ipytree                   0.2.2        A Tree Widget using jsTree
# ipywidgets                8.1.1        Jupyter interactive widgets
# iso8601                   2.1.0        Simple module to parse ISO 8601 dates
# jedi                      0.19.1       An autocompletion tool for Python th...
# jinja2                    3.1.2        A very fast and expressive template ...
# jsonschema                4.19.1       An implementation of JSON Schema val...
# jsonschema-specifications 2023.7.1     The JSON Schema meta-schemas and voc...
# jupyter-client            8.3.1        Jupyter protocol implementation and ...
# jupyter-core              5.3.2        Jupyter core package. A base package...
# jupyterlab-widgets        3.0.9        Jupyter interactive widgets for Jupy...
# kiwisolver                1.4.5        A fast implementation of the Cassowa...
# lxml                      4.9.3        Powerful and Pythonic XML processing...
# m3u8                      3.6.0        Python m3u8 parser
# markupsafe                2.1.3        Safely add untrusted strings to HTML...
# matplotlib                3.8.0        Python plotting package
# matplotlib-inline         0.1.6        Inline Matplotlib backend for Jupyter
# moviepy                   1.0.3        Video editing with Python
# mutagen                   1.47.0       read and write audio tags for many f...
# nest-asyncio              1.5.8        Patch asyncio to allow nested event ...
# notion                    0.0.28       Unofficial Python API client for Not...
# nuitka                    1.8.4        Python compiler with full language s...
# numpy                     1.26.0       Fundamental package for array comput...
# opencv-contrib-python     4.8.1.78     Wrapper package for OpenCV python bi...
# opencv-python             4.8.1.78     Wrapper package for OpenCV python bi...
# ordered-set               4.1.0        An OrderedSet is a custom MutableSet...
# orjson                    3.9.7        Fast, correct Python JSON library su...
# packaging                 23.2         Core utilities for Python packages
# pandas                    2.1.1        Powerful data structures for data an...
# parso                     0.8.3        A Python Parser
# pastedeploy               3.0.1        Load, configure, and compose WSGI ap...
# pdf2image                 1.16.3       A wrapper around the pdftoppm and pd...
# pexpect                   4.8.0        Pexpect allows easy control of inter...
# pickleshare               0.7.5        Tiny 'shelve'-like database with con...
# pillow                    9.5.0        Python Imaging Library (Fork)
# plaster                   1.1.2        A loader interface around multiple c...
# plaster-pastedeploy       1.0.1        A loader implementing the PasteDeplo...
# platformdirs              3.11.0       A small Python package for determini...
# player                    0.6.1        Pyramid view layers
# plotly                    5.17.0       An open-source, interactive data vis...
# plyer                     2.1.0        Platform-independent wrapper for pla...
# proglog                   0.1.10       Log and progress bar manager for con...
# prompt-toolkit            3.0.39       Library for building powerful intera...
# protobuf                  4.24.4
# psutil                    5.9.5        Cross-platform lib for process and s...
# ptyprocess                0.7.0        Run a subprocess in a pseudo terminal
# pure-eval                 0.2.2        Safely evaluate AST nodes without si...
# pyasn1                    0.5.0        Pure-Python implementation of ASN.1 ...
# pyasn1-modules            0.3.0        A collection of ASN.1-based protocol...
# pycryptodomex             3.19.0       Cryptographic library for Python
# pydantic                  2.4.2        Data validation using Python type hints
# pydantic-core             2.10.1
# pydub                     0.25.1       Manipulate audio with an simple and ...
# pygments                  2.16.1       Pygments is a syntax highlighting pa...
# pyparsing                 3.1.1        pyparsing module - Classes and metho...
# pypdf2                    3.0.1        A pure-python PDF library capable of...
# pyperclip                 1.8.2        A cross-platform clipboard module fo...
# pyramid                   2.0.2        The Pyramid Web Framework, a Pylons ...
# pyramid-jinja2            2.10         Jinja2 template bindings for the Pyr...
# pyshp                     2.3.1        Pure Python read/write support for E...
# python-box                7.1.1        Advanced Python dictionaries with do...
# python-dateutil           2.8.2        Extensions to the standard Python da...
# python-multipart          0.0.6        A streaming multipart parser for Python
# python-pptx               0.6.22       Generate and manipulate Open XML Pow...
# python-slugify            8.0.1        A Python slugify application that al...
# pytz                      2023.3.post1 World timezone definitions, modern a...
# pywin32                   306          Python for Window Extensions
# pyyaml                    6.0.1        YAML parser and emitter for Python
# pyzmq                     25.1.1       Python bindings for 0MQ
# rasterio                  1.3.8        Fast and direct raster I/O for use w...
# ratelim                   0.1.6        Makes it easy to respect rate limits.
# referencing               0.30.2       JSON Referencing + Python
# reportlab                 4.0.5        The Reportlab Toolkit
# requests                  2.31.0       Python HTTP for Humans.
# rpds-py                   0.10.4       Python bindings to Rust's persistent...
# rsa                       4.9          Pure-Python RSA implementation
# scooby                    0.7.4        A Great Dane turned Python environme...
# semantic-version          2.10.0       A library implementing the 'SemVer' ...
# setuptools                68.2.2       Easily download, build, install, upg...
# setuptools-scm            8.0.4        the blessed package to manage your v...
# six                       1.16.0       Python 2 and 3 compatibility utilities
# sniffio                   1.3.0        Sniff out which async library your c...
# snuggs                    1.4.7        Snuggs are s-expressions for Numpy
# soupsieve                 2.5          A modern CSS selector implementation...
# stack-data                0.6.3        Extract data from python stack frame...
# starlette                 0.27.0       The little ASGI library that shines.
# tenacity                  8.2.3        Retry code until it succeeds
# text-unidecode            1.3          The most basic Text::Unidecode port
# toolz                     0.12.0       List processing tools and functional...
# tornado                   6.3.3        Tornado is a Python web framework an...
# tqdm                      4.66.1       Fast, Extensible Progress Meter
# traitlets                 5.11.2       Traitlets Python configuration system
# traittypes                0.2.1        Scipy trait types
# translationstring         1.4          Utility library for i18n relied on b...
# twitch-dl                 2.1.3        Twitch downloader
# typing-extensions         4.8.0        Backported and Experimental Type Hin...
# tzdata                    2023.3       Provider of IANA time zone data
# tzlocal                   5.1          tzinfo object for the local timezone
# uritemplate               4.1.1        Implementation of RFC 6570 URI Templ...
# urllib3                   2.0.6        HTTP library with thread-safe connec...
# uvicorn                   0.23.2       The lightning-fast ASGI server.
# venusian                  3.0.0        A library for deferring decorator ac...
# wcwidth                   0.2.8        Measures the displayed width of unic...
# webob                     1.8.7        WSGI request and response object
# websockets                11.0.3       An implementation of the WebSocket P...
# widgetsnbextension        4.0.9        Jupyter interactive widgets for Jupy...
# xlsxwriter                3.1.6        A Python module for creating Excel X...
# xyzservices               2023.10.0    Source of XYZ tiles providers
# youtube-dl                2021.12.17   YouTube video downloader
# yt-dlp                    2023.9.24    A youtube-dl fork with additional fe...
# zope-deprecation          5.0          Zope Deprecation Infrastructure
# zope-interface            6.1          Interfaces for Python
# zstandard                 0.21.0       Zstandard bindings for Python

# %%
# !poetry add youtube-dl
# Out:
# Skipping virtualenv creation, as specified in config file.
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • youtube-dl
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.

# %%
# !poetry add pywin32
# Out:
# Skipping virtualenv creation, as specified in config file.
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • pywin32
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Nothing to add.

# %%
# !poetry update
# Out:
# Skipping virtualenv creation, as specified in config file.
# Updating dependencies
# Resolving dependencies... (58.6s)://files.pythonhosted.org/packages/51/ba/f6982db11e17b43da310a2169dcfbda166e8c509d8358ec8310219ca9732/XlsxWriter-3.1.7-py3-none-any.whl (14.5s)Resolving dependencies... (8.6s)Resolving dependencies... (12.0s)Resolving dependencies... (15.2s)Resolving dependencies... (15.9s)Resolving dependencies... (16.7s)Resolving dependencies... (20.6s)Resolving dependencies... (21.7s)Resolving dependencies... (31.5s)Resolving dependencies... (32.7s)Resolving dependencies... (48.7s)Resolving dependencies... (49.0s)Resolving dependencies... (56.3s)
#
# Package operations: 20 installs, 9 updates, 0 removals
#
#   • Updating google-auth (2.23.2 -> 2.23.3): Pending...
#   • Updating google-auth (2.23.2 -> 2.23.3): Downloading... 0%
#   • Updating google-auth (2.23.2 -> 2.23.3): Downloading... 11%
#   • Updating google-auth (2.23.2 -> 2.23.3): Downloading... 60%
#   • Updating google-auth (2.23.2 -> 2.23.3): Downloading... 100%
#   • Updating google-auth (2.23.2 -> 2.23.3): Installing...
#   • Updating google-auth (2.23.2 -> 2.23.3)
#   • Updating annotated-types (0.5.0 -> 0.6.0): Pending...
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Pending...
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 0%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 6%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 7%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 8%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 9%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 10%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 11%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 12%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 14%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 16%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 18%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 19%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 20%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 23%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 27%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 29%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 32%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 33%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 33%
#   • Updating annotated-types (0.5.0 -> 0.6.0): Downloading... 0%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 33%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 34%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 34%
#   • Updating annotated-types (0.5.0 -> 0.6.0): Downloading... 33%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 34%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 40%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 40%
#   • Updating annotated-types (0.5.0 -> 0.6.0): Downloading... 100%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 40%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 42%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 43%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 43%
#   • Updating annotated-types (0.5.0 -> 0.6.0): Installing...
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 43%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 44%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 50%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 60%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 68%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 70%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 74%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 78%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 79%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 90%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Downloading... 100%
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Installing...
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Installing...
#   • Updating annotated-types (0.5.0 -> 0.6.0)
#   • Updating google-api-python-client (2.102.0 -> 2.103.0): Installing...
#   • Updating google-api-python-client (2.102.0 -> 2.103.0)
#   • Updating fonttools (4.43.0 -> 4.43.1): Pending...
#   • Updating cycler (0.12.0 -> 0.12.1): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating cycler (0.12.0 -> 0.12.1): Downloading... 0%
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 0%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 20%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 80%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 80%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating cycler (0.12.0 -> 0.12.1): Downloading... 100%
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 80%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 80%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 80%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Downloading... 100%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 0%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Pending...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Downloading... 0%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Downloading... 100%
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 10%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 20%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 30%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 36%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 40%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 50%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 60%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 70%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 90%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Downloading... 100%
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0)
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating huggingface-hub (0.17.3 -> 0.18.0)
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1)
#   • Updating huggingface-hub (0.17.3 -> 0.18.0)
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating cycler (0.12.0 -> 0.12.1)
#   • Updating huggingface-hub (0.17.3 -> 0.18.0)
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating fonttools (4.43.0 -> 4.43.1)
#   • Updating cycler (0.12.0 -> 0.12.1)
#   • Updating huggingface-hub (0.17.3 -> 0.18.0)
#   • Updating jupyter-core (5.3.2 -> 5.4.0): Installing...
#   • Updating jupyter-core (5.3.2 -> 5.4.0)
#   • Installing imageio-ffmpeg (0.4.9): Pending...
#   • Installing matplotlib (3.8.0): Pending...
#   • Updating orjson (3.9.7 -> 3.9.8): Pending...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Pending...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 0%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 63%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 63%
#   • Updating orjson (3.9.7 -> 3.9.8): Downloading... 0%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 63%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 63%
#   • Updating orjson (3.9.7 -> 3.9.8): Downloading... 91%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 63%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 100%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 100%
#   • Updating orjson (3.9.7 -> 3.9.8): Downloading... 100%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Downloading... 100%
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Pending...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 0%
#   • Installing matplotlib (3.8.0): Pending...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Pending...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 5%
#   • Installing matplotlib (3.8.0): Pending...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 0%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 0%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 8%
#   • Installing matplotlib (3.8.0): Downloading... 0%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 4%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 4%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 10%
#   • Installing matplotlib (3.8.0): Downloading... 4%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 10%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 20%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 20%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 16%
#   • Installing matplotlib (3.8.0): Downloading... 20%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 20%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 20%
#   • Installing matplotlib (3.8.0): Downloading... 20%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 30%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 40%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 50%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 50%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 29%
#   • Installing matplotlib (3.8.0): Downloading... 50%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 55%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 60%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 60%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 36%
#   • Installing matplotlib (3.8.0): Downloading... 60%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 60%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 40%
#   • Installing matplotlib (3.8.0): Downloading... 60%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 70%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 80%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 47%
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 50%
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 51%
#   • Installing matplotlib (3.8.0): Downloading... 90%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Downloading... 100%
#   • Updating orjson (3.9.7 -> 3.9.8): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 60%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7): Installing...
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 70%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 80%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 86%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 90%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Downloading... 100%
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9): Installing...
#   • Installing matplotlib (3.8.0): Installing...
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0)
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing matplotlib (3.8.0)
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing imageio-ffmpeg (0.4.9)
#   • Installing matplotlib (3.8.0)
#   • Updating orjson (3.9.7 -> 3.9.8)
#   • Updating xlsxwriter (3.1.6 -> 3.1.7)
#   • Installing geemap (0.28.2): Pending...
#   • Installing gradio (3.47.1): Pending...
#   • Installing notion (0.0.28)
#   • Installing nuitka (1.8.4)
#   • Installing opencv-contrib-python (4.8.1.78)
#   • Installing opencv-python (4.8.1.78)
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing gradio (3.47.1): Downloading... 0%
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing gradio (3.47.1): Downloading... 0%
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing geemap (0.28.2): Downloading... 0%
#   • Installing gradio (3.47.1): Downloading... 0%
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing pdf2image (1.16.3): Downloading... 0%
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing pdf2image (1.16.3): Downloading... 35%
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing gradio (3.47.1): Downloading... 0%
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Downloading... 35%
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing geemap (0.28.2): Downloading... 6%
#   • Installing gradio (3.47.1): Downloading... 0%
#   • Installing moviepy (1.0.3): Pending...
#   • Installing pdf2image (1.16.3): Downloading... 35%
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing pdf2image (1.16.3): Downloading... 100%
#   • Installing player (0.6.1): Pending...
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing player (0.6.1): Downloading... 0%
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing player (0.6.1): Downloading... 0%
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 0%
#   • Installing plyer (2.1.0): Pending...
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing player (0.6.1): Downloading... 22%
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 22%
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing moviepy (1.0.3): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 22%
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing player (0.6.1): Downloading... 44%
#   • Installing plyer (2.1.0): Downloading... 0%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing plyer (2.1.0): Downloading... 11%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing moviepy (1.0.3): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 44%
#   • Installing plyer (2.1.0): Downloading... 11%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing gradio (3.47.1): Downloading... 1%
#   • Installing moviepy (1.0.3): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 44%
#   • Installing plyer (2.1.0): Downloading... 11%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing gradio (3.47.1): Downloading... 1%
#   • Installing moviepy (1.0.3): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 44%
#   • Installing plyer (2.1.0): Downloading... 11%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing geemap (0.28.2): Downloading... 10%
#   • Installing gradio (3.47.1): Downloading... 1%
#   • Installing moviepy (1.0.3): Downloading... 0%
#   • Installing pdf2image (1.16.3): Installing...
#   • Installing player (0.6.1): Downloading... 44%
#   • Installing plyer (2.1.0): Downloading... 11%
#   • Installing pypdf2 (3.0.1): Downloading... 0%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pypdf2 (3.0.1): Downloading... 10%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pywin32 (306): Failed
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   RuntimeError
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   Unable to find installation candidates for pywin32 (306)
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        69│
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        70│             links.append(link)
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        71│
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        72│         if not links:
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        74│
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        75│         # Get the best link
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#        77│
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pypdf2 (3.0.1): Downloading... 10%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 10%
#   • Installing python-pptx (0.6.22): Downloading... 0%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing player (0.6.1): Downloading... 100%
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing rasterio (1.3.8.post1): Downloading... 0%
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing player (0.6.1): Downloading... 100%
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 0%
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1): Downloading... 100%
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 0%
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Pending...
#   • Installing twitch-dl (2.1.3): Downloading... 0%
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1): Downloading... 100%
#   • Installing plyer (2.1.0): Downloading... 25%
#   • Installing pypdf2 (3.0.1): Downloading... 15%
#   • Installing python-pptx (0.6.22): Downloading... 9%
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 0%
#   • Installing reportlab (4.0.5): Pending...
#   • Installing twitch-dl (2.1.3): Downloading... 0%
#   • Installing moviepy (1.0.3): Downloading... 6%
# ...
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 100%
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing moviepy (1.0.3): Preparing...
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1): Preparing...
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 100%
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing gradio (3.47.1): Downloading... 93%
#   • Installing moviepy (1.0.3): Preparing...
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1): Preparing...
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Downloading... 100%
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing player (0.6.1): Installing...
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing moviepy (1.0.3): Installing...
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7): Installing...
#   • Installing yt-dlp (2023.10.7)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing gradio (3.47.1): Downloading... 100%
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing gradio (3.47.1): Installing...
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1): Installing...
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing rasterio (1.3.8.post1)
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1)
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
#   • Installing gradio (3.47.1)
#   • Installing moviepy (1.0.3)
#   • Installing pdf2image (1.16.3)
#   • Installing player (0.6.1)
#   • Installing plyer (2.1.0)
#   • Installing pypdf2 (3.0.1)
#   • Installing python-pptx (0.6.22)
#   • Installing pywin32 (306): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pywin32 (306)
#
#   at /usr/local/lib/python3.11/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing rasterio (1.3.8.post1)
#   • Installing reportlab (4.0.5)
#   • Installing twitch-dl (2.1.3)
#   • Installing youtube-dl (2021.12.17)
#   • Installing yt-dlp (2023.10.7)
